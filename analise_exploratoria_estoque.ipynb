# %% [markdown]
# # Análise Exploratória de Dados (EDA)
#
# Projeto: *** Previsão de Estoque Inteligente com AWS SageMaker Canvas ***
#
# Este notebook realiza uma análise exploratória simples do dataset utilizado no Canvas, com foco em entendimento dos dados, estatísticas descritivas e possíveis insights de negócio.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (8,4)

# %%
df = pd.read_csv('LAB-AWS-SAGEMAKER-CANVAS-ESTOQUE/datasets/dataset-1000-promo.csv')
df.head()

# %% [markdown]
# # Estrutura do Dataset
#
# * Quantidade de linhas e colunas
# * Tipos de dados

# %%
df.shape, df.dtypes

# %% [markdown]
# # Estatísticas Descritivas
#
# Análise das principais métricas numéricas para entender o comportamento do estoque, preços e possíveis variações causadas por promoções.

# %%
df.describe()

# %% [markdown]
# # Insights Iniciais
#
# * Promoções podem impactar diretamente o volume de vendas.
# * A renovação de estoque ajuda a evitar rupturas.
# * Esses padrões são aprendidos automaticamente pelo SageMaker Canvas.
